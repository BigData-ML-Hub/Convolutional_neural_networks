# %% [markdown]
# # Ungraded Lab: Data Augmentation
#
# In the previous lessons, you saw that having a high training accuracy does not automatically mean having a good predictive model. It can still perform poorly on new data because it has overfit to the training set. In this lab, you will see how to avoid that using _data augmentation_. This increases the amount of training data by modifying the existing training data's properties. For example, in image data, you can apply different preprocessing techniques such as rotate, flip, shear, or zoom on your existing images so you can simulate other data that the model should also learn from. This way, the model would see more variety in the images during training so it will infer better on new, previously unseen data.
#
# Let's see how you can do this in the following sections.

# %% [markdown]
# ## Baseline Performance
#
# You will start with a model that's very effective at learning `Cats vs Dogs` without data augmentation. It's similar to the previous models that you have used. Note that there are four convolutional layers with 32, 64, 128 and 128 convolutions respectively. The code is basically the same from the previous lab so we won't go over the details step by step since you've already seen it before.

# %%
# First import the necessary libraries
import os
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# 2025-07-25 23:22:16.381549: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-25 23:22:16.408862: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-25 23:22:16.884461: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# import os
# import random

# def split_data_only_os(base_path='PetImages', split_ratio=0.8):
#     categories = ['Cat', 'Dog']
#     main_path = os.path.join(base_path, 'main')

#     for category in categories:
#         src_dir = os.path.join(base_path, category)
#         files = [f for f in os.listdir(src_dir) if os.path.isfile(os.path.join(src_dir, f))]
#         random.shuffle(files)

#         split_index = int(len(files) * split_ratio)
#         train_files = files[:split_index]
#         val_files = files[split_index:]

#         # Create train and validation dirs
#         train_dir = os.path.join(main_path, 'train', category)
#         val_dir = os.path.join(main_path, 'validation', category)
#         os.makedirs(train_dir, exist_ok=True)
#         os.makedirs(val_dir, exist_ok=True)

#         # Move train files
#         for f in train_files:
#             src = os.path.join(src_dir, f)
#             dst = os.path.join(train_dir, f)
#             os.rename(src, dst)

#         # Move validation files
#         for f in val_files:
#             src = os.path.join(src_dir, f)
#             dst = os.path.join(val_dir, f)
#             os.rename(src, dst)

# split_data_only_os()

# %%
BASE_DIR = 'PetImages'

train_dir = os.path.join(BASE_DIR, 'train')
validation_dir = os.path.join(BASE_DIR, 'validation')

# Directory with training cat/dog pictures
train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')

# Directory with validation cat/dog pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

print(f"Contents of base directory: {os.listdir(BASE_DIR)}")

print(f"\nContents of train directory: {os.listdir(train_dir)}")

print(f"\nContents of validation directory: {os.listdir(validation_dir)}")
# Out:
# Contents of base directory: ['train', 'validation']
#
# Contents of train directory: ['Cat', 'Dog']
#
# Contents of validation directory: ['Cat', 'Dog']

# %% [markdown]
# # Cleaning broken images

# %%
from PIL import Image
import os

bad_modes = []

folders = [
    "PetImages/train/Cat", "PetImages/train/Dog", 
    "PetImages/validation/Cat", "PetImages/validation/Dog",
]

for folder in folders:
    for filename in os.listdir(folder):
        path = os.path.join(folder, filename)
        try:
            with Image.open(path) as img:
                mode = img.mode
                if mode not in ['RGB', 'L']:
                    print(f"Deleting {path} with mode: {mode}")
                    os.remove(path)
        except Exception as e:
            print(f"Removing corrupt image {path}: {e}")
            os.remove(path)
# Out:
# Deleting PetImages/train/Cat/11095.jpg with mode: P
# Removing corrupt image PetImages/train/Cat/666.jpg: cannot identify image file '/home/harishi/common_drive/Downloads/projects/BigData-ML-Hub/Convolutional_neural_networks/Week_2/PetImages/train/Cat/666.jpg'
# Deleting PetImages/train/Cat/140.jpg with mode: P
# Deleting PetImages/train/Cat/2663.jpg with mode: P
# Deleting PetImages/train/Cat/11874.jpg with mode: P
# Deleting PetImages/train/Cat/8470.jpg with mode: P
# Deleting PetImages/train/Cat/9565.jpg with mode: P
# Deleting PetImages/train/Cat/7968.jpg with mode: P
# Deleting PetImages/train/Cat/7978.jpg with mode: P
# Deleting PetImages/train/Cat/6435.jpg with mode: P
# Deleting PetImages/train/Cat/660.jpg with mode: P
# Deleting PetImages/train/Cat/9171.jpg with mode: P
# Deleting PetImages/train/Cat/11565.jpg with mode: P
# Removing corrupt image PetImages/train/Cat/Thumbs.db: cannot identify image file '/home/harishi/common_drive/Downloads/projects/BigData-ML-Hub/Convolutional_neural_networks/Week_2/PetImages/train/Cat/Thumbs.db'
# Deleting PetImages/train/Cat/9778.jpg with mode: P
# Deleting PetImages/train/Cat/3300.jpg with mode: P
# Deleting PetImages/train/Cat/5553.jpg with mode: P
# Deleting PetImages/train/Cat/936.jpg with mode: P
# Deleting PetImages/train/Cat/11210.jpg with mode: P
# Deleting PetImages/train/Cat/10820.jpg with mode: P
# Deleting PetImages/train/Cat/5370.jpg with mode: P
# Deleting PetImages/train/Dog/7459.jpg with mode: P
# Deleting PetImages/train/Dog/7133.jpg with mode: P
# Deleting PetImages/train/Dog/6318.jpg with mode: P
# Deleting PetImages/train/Dog/4367.jpg with mode: P
# Deleting PetImages/train/Dog/11675.jpg with mode: P
# Deleting PetImages/train/Dog/7969.jpg with mode: P
# Deleting PetImages/train/Dog/5604.jpg with mode: P
# Deleting PetImages/train/Dog/3288.jpg with mode: P
# Deleting PetImages/train/Dog/11285.jpg with mode: RGBA
# Deleting PetImages/train/Dog/2688.jpg with mode: P
# Deleting PetImages/train/Dog/1259.jpg with mode: P
# Deleting PetImages/train/Dog/6245.jpg with mode: CMYK
# Deleting PetImages/train/Dog/1789.jpg with mode: CMYK
# Deleting PetImages/train/Dog/6718.jpg with mode: P
# Deleting PetImages/train/Dog/10747.jpg with mode: P
# Deleting PetImages/train/Dog/8730.jpg with mode: P
# Deleting PetImages/train/Dog/9078.jpg with mode: CMYK
# Deleting PetImages/train/Dog/11410.jpg with mode: P
# Deleting PetImages/train/Dog/3588.jpg with mode: P
# Deleting PetImages/train/Dog/10401.jpg with mode: P
# Deleting PetImages/train/Dog/7514.jpg with mode: RGBA
# Deleting PetImages/train/Dog/1866.jpg with mode: P
# Deleting PetImages/train/Dog/10797.jpg with mode: P
# Deleting PetImages/train/Dog/2877.jpg with mode: P
# Deleting PetImages/train/Dog/2384.jpg with mode: P
# Deleting PetImages/train/Dog/3136.jpg with mode: P
# Deleting PetImages/train/Dog/7112.jpg with mode: P
# Deleting PetImages/train/Dog/9188.jpg with mode: P
# /home/harishi/.local/lib/python3.10/site-packages/PIL/TiffImagePlugin.py:890: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# Deleting PetImages/train/Dog/10158.jpg with mode: P
# Deleting PetImages/validation/Cat/3491.jpg with mode: P
# Deleting PetImages/validation/Cat/10501.jpg with mode: P
# Deleting PetImages/validation/Cat/11935.jpg with mode: P
# Deleting PetImages/validation/Cat/12080.jpg with mode: P
# Deleting PetImages/validation/Cat/4833.jpg with mode: P
# Deleting PetImages/validation/Cat/850.jpg with mode: P
# Deleting PetImages/validation/Cat/10125.jpg with mode: P
# Removing corrupt image PetImages/validation/Dog/11702.jpg: cannot identify image file '/home/harishi/common_drive/Downloads/projects/BigData-ML-Hub/Convolutional_neural_networks/Week_2/PetImages/validation/Dog/11702.jpg'
# Deleting PetImages/validation/Dog/6059.jpg with mode: P
# Deleting PetImages/validation/Dog/7369.jpg with mode: P
# Deleting PetImages/validation/Dog/5736.jpg with mode: P
# Removing corrupt image PetImages/validation/Dog/Thumbs.db: cannot identify image file '/home/harishi/common_drive/Downloads/projects/BigData-ML-Hub/Convolutional_neural_networks/Week_2/PetImages/validation/Dog/Thumbs.db'
# Deleting PetImages/validation/Dog/11849.jpg with mode: P
# Deleting PetImages/validation/Dog/11853.jpg with mode: P
# Deleting PetImages/validation/Dog/6238.jpg with mode: P
# Deleting PetImages/validation/Dog/1308.jpg with mode: P

# %%
from PIL import Image
import os

folders = [
    "PetImages/train/Cat", "PetImages/train/Dog", 
    "PetImages/validation/Cat", "PetImages/validation/Dog",
]

for folder in folders:
    for filename in os.listdir(folder):
        path = os.path.join(folder, filename)
        try:
            with Image.open(path) as img:
                if img.mode != 'RGB':
                    img = img.convert('RGB')
                    img.save(path)
        except Exception as e:
            print(f"Removing {path}: {e}")
            os.remove(path)

# %%
import os
import glob
import tensorflow as tf

# Change this to your actual dataset base directory
base_dir = "PetImages"

# Grab all image paths under base_dir (train/val/test)
img_paths = glob.glob(os.path.join(base_dir, '*/*/*.jpg')) + \
            glob.glob(os.path.join(base_dir, '*/*/*.jpeg')) + \
            glob.glob(os.path.join(base_dir, '*/*/*.png'))

print(f"Total images found: {len(img_paths)}")

bad_paths = []

for image_path in img_paths:
    try:
        img_bytes = tf.io.read_file(image_path)
        _ = tf.io.decode_image(img_bytes, channels=3)  # Force decode as RGB
    except tf.errors.InvalidArgumentError as e:
        print(f"Found corrupt image: {image_path} | {e}")
        bad_paths.append(image_path)

print("\nRemoving bad images...")

for bad_path in bad_paths:
    os.remove(bad_path)
    print(f"Removed: {bad_path}")

print(f"\n✅ Cleanup complete. Removed {len(bad_paths)} corrupt images.")
# Out:
# Total images found: 24936
# 2025-07-25 23:24:22.987844: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-07-25 23:24:22.987865: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:168] retrieving CUDA diagnostic information for host: CLU
# 2025-07-25 23:24:22.987868: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:175] hostname: CLU
# 2025-07-25 23:24:22.987929: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:199] libcuda reported version is: 550.144.3
# 2025-07-25 23:24:22.987939: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:203] kernel reported version is: 550.144.3
# 2025-07-25 23:24:22.987942: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:309] kernel version seems to match DSO: 550.144.3
# Found corrupt image: PetImages/train/Cat/4351.jpg | {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Input size should match (header_size + row_size * abs_height) but they differ by 2 [Op:DecodeImage] name:
# Corrupt JPEG data: 99 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 1153 extraneous bytes before marker 0xd9
# Found corrupt image: PetImages/train/Cat/10404.jpg | {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Corrupt JPEG data: 128 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 1403 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 396 extraneous bytes before marker 0xd9
# Found corrupt image: PetImages/train/Dog/11912.jpg | {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Number of channels inherent in the image must be 1, 3 or 4, was 2 [Op:DecodeImage] name:
# Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
# Found corrupt image: PetImages/train/Dog/11233.jpg | {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Number of channels inherent in the image must be 1, 3 or 4, was 2 [Op:DecodeImage] name:
# Found corrupt image: PetImages/train/Dog/2317.jpg | {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Number of channels inherent in the image must be 1, 3 or 4, was 2 [Op:DecodeImage] name:
# Warning: unknown JFIF revision number 0.00
# Found corrupt image: PetImages/train/Dog/2494.jpg | {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Input size should match (header_size + row_size * abs_height) but they differ by 2 [Op:DecodeImage] name:
# Corrupt JPEG data: 228 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 65 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 239 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 214 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 2226 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 252 extraneous bytes before marker 0xd9
# Found corrupt image: PetImages/validation/Dog/9500.jpg | {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Number of channels inherent in the image must be 1, 3 or 4, was 2 [Op:DecodeImage] name:
#
# Removing bad images...
# Removed: PetImages/train/Cat/4351.jpg
# Removed: PetImages/train/Cat/10404.jpg
# Removed: PetImages/train/Dog/11912.jpg
# Removed: PetImages/train/Dog/11233.jpg
# Removed: PetImages/train/Dog/2317.jpg
# Removed: PetImages/train/Dog/2494.jpg
# Removed: PetImages/validation/Dog/9500.jpg
#
# ✅ Cleanup complete. Removed 7 corrupt images.

# %%
BASE_DIR = 'PetImages'

train_dir = os.path.join(BASE_DIR, 'train')
validation_dir = os.path.join(BASE_DIR, 'validation')

# Directory with training cat/dog pictures
train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')

# Directory with validation cat/dog pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

print(f"Contents of base directory: {os.listdir(BASE_DIR)}")

print(f"\nContents of train directory: {os.listdir(train_dir)}")

print(f"\nContents of validation directory: {os.listdir(validation_dir)}")
# Out:
# Contents of base directory: ['train', 'validation']
#
# Contents of train directory: ['Cat', 'Dog']
#
# Contents of validation directory: ['Cat', 'Dog']

# %% [markdown]
# You will place the model creation inside a function so you can easily initialize a new one when you use data augmentation later in this notebook.

# %%
def create_model():
    '''Creates a CNN with 4 convolutional layers'''
    model = tf.keras.models.Sequential([
        tf.keras.Input(shape=(150, 150, 3)),
        tf.keras.layers.Rescaling(1./255),
        tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    return model

# %% [markdown]
# You will preprocess the training and validation datasets as usual.

# %%
# Instantiate the training dataset
train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(150, 150),
    batch_size=20,
    label_mode='binary'
    )

# Instantiate the validation dataset
validation_dataset = tf.keras.utils.image_dataset_from_directory(
    validation_dir,
    image_size=(150, 150),
    batch_size=20,
    label_mode='binary'
    )

# Optimize the datasets for training
SHUFFLE_BUFFER_SIZE = 1000
PREFETCH_BUFFER_SIZE = tf.data.AUTOTUNE

train_dataset_final = (train_dataset
                       .cache()
                       .shuffle(SHUFFLE_BUFFER_SIZE)
                       .prefetch(PREFETCH_BUFFER_SIZE)
                       )

validation_dataset_final = (validation_dataset
                            .cache()
                            .prefetch(PREFETCH_BUFFER_SIZE)
                            )
# Out:
# Found 19944 files belonging to 2 classes.
# Found 4985 files belonging to 2 classes.

# %% [markdown]
# You will train only for 20 epochs to save time but feel free to increase this if you want.

# %%
# Constant for epochs
EPOCHS = 20

# Create a new model
model = create_model()

# Setup the training parameters
model.compile(loss='binary_crossentropy',
              optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-4),
              metrics=['accuracy'])

# Train the model
history = model.fit(
      train_dataset_final,
      epochs=EPOCHS,
      validation_data=validation_dataset_final,
      verbose=2)
# Out:
# Epoch 1/20
# 998/998 - 71s - loss: 0.6237 - accuracy: 0.6422 - val_loss: 0.5257 - val_accuracy: 0.7448 - 71s/epoch - 71ms/step
# Epoch 2/20
# 998/998 - 73s - loss: 0.5047 - accuracy: 0.7526 - val_loss: 0.5177 - val_accuracy: 0.7428 - 73s/epoch - 73ms/step
# Epoch 3/20
# 998/998 - 74s - loss: 0.4400 - accuracy: 0.7973 - val_loss: 0.4085 - val_accuracy: 0.8058 - 74s/epoch - 74ms/step
# Epoch 4/20
# 998/998 - 77s - loss: 0.3991 - accuracy: 0.8189 - val_loss: 0.3800 - val_accuracy: 0.8259 - 77s/epoch - 77ms/step
# Epoch 5/20
# 998/998 - 77s - loss: 0.3662 - accuracy: 0.8361 - val_loss: 0.4214 - val_accuracy: 0.8146 - 77s/epoch - 77ms/step
# Epoch 6/20
# 998/998 - 77s - loss: 0.3349 - accuracy: 0.8529 - val_loss: 0.3417 - val_accuracy: 0.8435 - 77s/epoch - 77ms/step
# Epoch 7/20
# 998/998 - 78s - loss: 0.3054 - accuracy: 0.8685 - val_loss: 0.3383 - val_accuracy: 0.8554 - 78s/epoch - 78ms/step
# Epoch 8/20
# 998/998 - 77s - loss: 0.2789 - accuracy: 0.8827 - val_loss: 0.3189 - val_accuracy: 0.8618 - 77s/epoch - 77ms/step
# Epoch 9/20
# 998/998 - 77s - loss: 0.2510 - accuracy: 0.8936 - val_loss: 0.3109 - val_accuracy: 0.8638 - 77s/epoch - 77ms/step
# Epoch 10/20
# 998/998 - 77s - loss: 0.2221 - accuracy: 0.9090 - val_loss: 0.2986 - val_accuracy: 0.8720 - 77s/epoch - 77ms/step
# Epoch 11/20
# 998/998 - 77s - loss: 0.1945 - accuracy: 0.9199 - val_loss: 0.3061 - val_accuracy: 0.8762 - 77s/epoch - 77ms/step
# Epoch 12/20
# 998/998 - 77s - loss: 0.1672 - accuracy: 0.9305 - val_loss: 0.3597 - val_accuracy: 0.8590 - 77s/epoch - 78ms/step
# Epoch 13/20
# 998/998 - 78s - loss: 0.1406 - accuracy: 0.9444 - val_loss: 0.3289 - val_accuracy: 0.8772 - 78s/epoch - 78ms/step
# Epoch 14/20
# 998/998 - 78s - loss: 0.1178 - accuracy: 0.9549 - val_loss: 0.3291 - val_accuracy: 0.8720 - 78s/epoch - 78ms/step
# Epoch 15/20
# 998/998 - 78s - loss: 0.0953 - accuracy: 0.9638 - val_loss: 0.3357 - val_accuracy: 0.8748 - 78s/epoch - 78ms/step
# Epoch 16/20
# 998/998 - 78s - loss: 0.0756 - accuracy: 0.9730 - val_loss: 0.4211 - val_accuracy: 0.8674 - 78s/epoch - 78ms/step
# Epoch 17/20
# 998/998 - 78s - loss: 0.0581 - accuracy: 0.9790 - val_loss: 0.4146 - val_accuracy: 0.8726 - 78s/epoch - 78ms/step
# Epoch 18/20
# 998/998 - 77s - loss: 0.0461 - accuracy: 0.9838 - val_loss: 0.4165 - val_accuracy: 0.8726 - 77s/epoch - 77ms/step
# Epoch 19/20
# 998/998 - 77s - loss: 0.0371 - accuracy: 0.9884 - val_loss: 0.5175 - val_accuracy: 0.8666 - 77s/epoch - 78ms/step
# Epoch 20/20
# 998/998 - 78s - loss: 0.0279 - accuracy: 0.9904 - val_loss: 0.4876 - val_accuracy: 0.8760 - 78s/epoch - 78ms/step

# %% [markdown]
# You will then visualize the loss and accuracy with respect to the training and validation set. You will again use a convenience function so it can be reused later. This function accepts a [History](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/History) object which contains the results of the `fit()` method you ran above.

# %%
def plot_loss_acc(history):
    '''Plots the training and validation loss and accuracy from a history object'''
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(acc))

    fig, ax = plt.subplots(1,2, figsize=(12, 6))
    ax[0].plot(epochs, acc, 'bo', label='Training accuracy')
    ax[0].plot(epochs, val_acc, 'b', label='Validation accuracy')
    ax[0].set_title('Training and validation accuracy')
    ax[0].set_xlabel('epochs')
    ax[0].set_ylabel('accuracy')
    ax[0].legend()

    ax[1].plot(epochs, loss, 'bo', label='Training Loss')
    ax[1].plot(epochs, val_loss, 'b', label='Validation Loss')
    ax[1].set_title('Training and validation loss')
    ax[1].set_xlabel('epochs')
    ax[1].set_ylabel('loss')
    ax[1].legend()

    plt.show()

# %%
# Plot training results
plot_loss_acc(history)

# %% [markdown]
# From the results above, you'll see the training accuracy is more than 90%, and the validation accuracy is in the 70%-80% range. This is a great example of _overfitting_ -- which in short means that it can do very well with images it has seen before, but not so well with images it hasn't.

# %% [markdown]
# ## Data augmentation
#
# One simple method to avoid overfitting is to augment the images. If you think about it, most pictures of a cat are very similar -- the ears are at the top, the eyes are below the ears etc. Things like the distance between the eyes and ears will always be quite similar too.
#
# What if you tweak with the images a bit -- rotate the image, squash it, etc.  That's what image augementation is all about.
#
# To do that, you will build a data augmentation model with [preprocessing layers for image augmentation](https://www.tensorflow.org/guide/keras/preprocessing_layers#image_data_augmentation). This will transform the data during training to introduce variations of the same image. Let's quickly go over the layers you will use in this exercise.
#
# * [RandomFlip](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomFlip) is for randomly flipping the images horizontally, vertically, or both.
# * [RandomRotation](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomRotation) rotates the image by an angle within a given range.
# * [RandomTranslation](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomTranslation) shifts pictures vertically and horizontally.
# * [RandomZoom](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomZoom) zooms into or out of the images.
#
# In addition, some of these layers have a `fill_mode` parameter. This is the strategy used for filling newly created pixels, which can appear after a rotation or a width/height shift.
#
# The code below will create this model with some set parameters. After you complete this lab, feel free to modify these and see the impact on the results.

# %%
# Define fill mode.
FILL_MODE = 'nearest'

# Create the augmentation model.
data_augmentation = tf.keras.Sequential([
    # Specify the input shape.
    tf.keras.Input(shape=(150,150,3)),
    # Add the augmentation layers
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.2, fill_mode=FILL_MODE),
    tf.keras.layers.RandomTranslation(0.2,0.2, fill_mode=FILL_MODE),
    tf.keras.layers.RandomZoom(0.2, fill_mode=FILL_MODE)
    ])

# %% [markdown]
# You will define a utility function that lets you preview how the transformed images look like. It will take in a sample image, then output a given number of augmented images using the model you defined above.

# %%
def demo_augmentation(sample_image, model, num_aug):
    '''Takes a single image array, then uses a model to generate num_aug transformations'''

    # Instantiate preview list
    image_preview = []

    # Convert input image to a PIL image instance
    sample_image_pil = tf.keras.utils.array_to_img(sample_image)

    # Append the result to the list
    image_preview.append(sample_image_pil)

    # Apply the image augmentation and append the results to the list
    for i in range(NUM_AUG):
        sample_image_aug = model(tf.expand_dims(sample_image, axis=0))
        sample_image_aug_pil = tf.keras.utils.array_to_img(tf.squeeze(sample_image_aug))
        image_preview.append(sample_image_aug_pil)

    # Instantiate a subplot
    fig, axes = plt.subplots(1, NUM_AUG + 1, figsize=(12, 12))

    # Preview the images.
    for index, ax in enumerate(axes):
        ax.imshow(image_preview[index])
        ax.set_axis_off()

        if index == 0:
            ax.set_title('original')
        else:
            ax.set_title(f'augment {index}')

# %% [markdown]
# Now get some images from the dataset.

# %%
# Get a batch of images
sample_batch = list(train_dataset.take(1))[0][0]
print(f'images per batch: {len(sample_batch)}')
# Out:
# images per batch: 20

# %% [markdown]
# This will show sample transformations for the first 4 images of the sample batch. Notice that each call of the `data_augmentation` model yields a different output. It's like adding more images to your dataset without you having to collect them manually.

# %%
NUM_AUG = 4

# Apply the transformations to the first 4 images
demo_augmentation(sample_batch[0], data_augmentation, NUM_AUG)
demo_augmentation(sample_batch[1], data_augmentation, NUM_AUG)
demo_augmentation(sample_batch[2], data_augmentation, NUM_AUG)
demo_augmentation(sample_batch[3], data_augmentation, NUM_AUG)

# Uncomment the line below to delete the variable to free up some memory
# del sample_batch

# %% [markdown]
# Now that you see what the preprocessing layers do, you can prepend these to the base model so it can generate transformed images to the base model. Do note that these layers are only active while training. They are automatically disabled during prediction and evaluation.

# %%
# Instantiate the base model
model_without_aug = create_model()

# Prepend the data augmentation layers to the base model
model_with_aug = tf.keras.models.Sequential([
    data_augmentation,
    model_without_aug
])

# Compile the model
model_with_aug.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-4),
    metrics=['accuracy'])

# %% [markdown]
# Because you now have virtually more data, it will also take the model more time to learn the relevant features. Without data augmentation, your model already started overfitting to the training set within 20 epochs. Try training this model for 80 epochs and observe the results.

# %%
EPOCHS=80

# Train the new model
history_with_aug = model_with_aug.fit(
      train_dataset_final,
      epochs=EPOCHS,
      validation_data=validation_dataset_final,
      verbose=2)
# Out:
# Epoch 1/80
# 998/998 - 84s - loss: 0.6663 - accuracy: 0.5806 - val_loss: 0.6002 - val_accuracy: 0.6857 - 84s/epoch - 84ms/step
# Epoch 2/80
# 998/998 - 84s - loss: 0.6180 - accuracy: 0.6546 - val_loss: 0.5648 - val_accuracy: 0.7053 - 84s/epoch - 84ms/step
# Epoch 3/80
# 998/998 - 84s - loss: 0.5937 - accuracy: 0.6808 - val_loss: 0.6312 - val_accuracy: 0.6606 - 84s/epoch - 84ms/step
# Epoch 4/80
# 998/998 - 83s - loss: 0.5767 - accuracy: 0.6943 - val_loss: 0.5085 - val_accuracy: 0.7661 - 83s/epoch - 83ms/step
# Epoch 5/80
# 998/998 - 84s - loss: 0.5553 - accuracy: 0.7155 - val_loss: 0.4879 - val_accuracy: 0.7687 - 84s/epoch - 84ms/step
# Epoch 6/80
# 998/998 - 83s - loss: 0.5416 - accuracy: 0.7243 - val_loss: 0.4872 - val_accuracy: 0.7603 - 83s/epoch - 84ms/step
# Epoch 7/80
# 998/998 - 84s - loss: 0.5295 - accuracy: 0.7301 - val_loss: 0.5197 - val_accuracy: 0.7360 - 84s/epoch - 84ms/step
# Epoch 8/80
# 998/998 - 83s - loss: 0.5222 - accuracy: 0.7400 - val_loss: 0.4447 - val_accuracy: 0.7998 - 83s/epoch - 83ms/step
# Epoch 9/80
# 998/998 - 83s - loss: 0.5086 - accuracy: 0.7457 - val_loss: 0.5053 - val_accuracy: 0.7601 - 83s/epoch - 83ms/step
# Epoch 10/80
# 998/998 - 84s - loss: 0.4996 - accuracy: 0.7592 - val_loss: 0.4278 - val_accuracy: 0.8032 - 84s/epoch - 84ms/step
# Epoch 11/80
# 998/998 - 83s - loss: 0.4897 - accuracy: 0.7635 - val_loss: 0.4182 - val_accuracy: 0.8114 - 83s/epoch - 84ms/step
# Epoch 12/80
# 998/998 - 84s - loss: 0.4787 - accuracy: 0.7703 - val_loss: 0.4747 - val_accuracy: 0.7801 - 84s/epoch - 84ms/step
# Epoch 13/80
# 998/998 - 84s - loss: 0.4706 - accuracy: 0.7757 - val_loss: 0.4393 - val_accuracy: 0.8042 - 84s/epoch - 84ms/step
# Epoch 14/80
# 998/998 - 83s - loss: 0.4613 - accuracy: 0.7806 - val_loss: 0.5317 - val_accuracy: 0.7609 - 83s/epoch - 83ms/step
# Epoch 15/80
# 998/998 - 84s - loss: 0.4527 - accuracy: 0.7857 - val_loss: 0.4492 - val_accuracy: 0.7944 - 84s/epoch - 84ms/step
# Epoch 16/80
# 998/998 - 84s - loss: 0.4378 - accuracy: 0.7953 - val_loss: 0.4143 - val_accuracy: 0.8090 - 84s/epoch - 84ms/step
# Epoch 17/80
# 998/998 - 83s - loss: 0.4313 - accuracy: 0.8021 - val_loss: 0.4153 - val_accuracy: 0.8148 - 83s/epoch - 84ms/step
# Epoch 18/80
# 998/998 - 83s - loss: 0.4218 - accuracy: 0.8018 - val_loss: 0.3716 - val_accuracy: 0.8313 - 83s/epoch - 84ms/step
# Epoch 19/80
# 998/998 - 83s - loss: 0.4138 - accuracy: 0.8060 - val_loss: 0.3806 - val_accuracy: 0.8233 - 83s/epoch - 84ms/step
# Epoch 20/80
# 998/998 - 85s - loss: 0.4084 - accuracy: 0.8134 - val_loss: 0.3811 - val_accuracy: 0.8299 - 85s/epoch - 85ms/step
# Epoch 21/80
# 998/998 - 83s - loss: 0.3981 - accuracy: 0.8179 - val_loss: 0.3434 - val_accuracy: 0.8510 - 83s/epoch - 83ms/step
# Epoch 22/80
# 998/998 - 84s - loss: 0.3956 - accuracy: 0.8213 - val_loss: 0.3534 - val_accuracy: 0.8407 - 84s/epoch - 84ms/step
# Epoch 23/80
# 998/998 - 84s - loss: 0.3848 - accuracy: 0.8265 - val_loss: 0.3379 - val_accuracy: 0.8508 - 84s/epoch - 84ms/step
# Epoch 24/80
# 998/998 - 83s - loss: 0.3796 - accuracy: 0.8269 - val_loss: 0.3347 - val_accuracy: 0.8536 - 83s/epoch - 83ms/step
# Epoch 25/80
# 998/998 - 83s - loss: 0.3690 - accuracy: 0.8343 - val_loss: 0.3485 - val_accuracy: 0.8495 - 83s/epoch - 84ms/step
# Epoch 26/80
# 998/998 - 84s - loss: 0.3600 - accuracy: 0.8379 - val_loss: 0.3522 - val_accuracy: 0.8461 - 84s/epoch - 84ms/step
# Epoch 27/80
# 998/998 - 84s - loss: 0.3597 - accuracy: 0.8390 - val_loss: 0.3407 - val_accuracy: 0.8526 - 84s/epoch - 84ms/step
# Epoch 28/80
# 998/998 - 83s - loss: 0.3468 - accuracy: 0.8462 - val_loss: 0.3613 - val_accuracy: 0.8407 - 83s/epoch - 83ms/step
# Epoch 29/80
# 998/998 - 84s - loss: 0.3399 - accuracy: 0.8464 - val_loss: 0.3499 - val_accuracy: 0.8485 - 84s/epoch - 84ms/step
# Epoch 30/80
# 998/998 - 84s - loss: 0.3443 - accuracy: 0.8446 - val_loss: 0.2955 - val_accuracy: 0.8766 - 84s/epoch - 84ms/step
# Epoch 31/80
# 998/998 - 83s - loss: 0.3335 - accuracy: 0.8497 - val_loss: 0.3299 - val_accuracy: 0.8586 - 83s/epoch - 84ms/step
# Epoch 32/80
# 998/998 - 83s - loss: 0.3284 - accuracy: 0.8544 - val_loss: 0.3155 - val_accuracy: 0.8672 - 83s/epoch - 83ms/step
# Epoch 33/80
# 998/998 - 84s - loss: 0.3250 - accuracy: 0.8573 - val_loss: 0.2903 - val_accuracy: 0.8754 - 84s/epoch - 84ms/step
# Epoch 34/80
# 998/998 - 83s - loss: 0.3179 - accuracy: 0.8620 - val_loss: 0.3067 - val_accuracy: 0.8722 - 83s/epoch - 83ms/step
# Epoch 35/80
# 998/998 - 84s - loss: 0.3124 - accuracy: 0.8633 - val_loss: 0.3545 - val_accuracy: 0.8397 - 84s/epoch - 84ms/step
# Epoch 36/80
# 998/998 - 83s - loss: 0.3087 - accuracy: 0.8661 - val_loss: 0.2914 - val_accuracy: 0.8748 - 83s/epoch - 84ms/step
# Epoch 37/80
# 998/998 - 83s - loss: 0.3088 - accuracy: 0.8653 - val_loss: 0.3053 - val_accuracy: 0.8676 - 83s/epoch - 84ms/step
# Epoch 38/80
# 998/998 - 83s - loss: 0.3041 - accuracy: 0.8675 - val_loss: 0.2935 - val_accuracy: 0.8712 - 83s/epoch - 83ms/step
# Epoch 39/80
# 998/998 - 83s - loss: 0.2995 - accuracy: 0.8701 - val_loss: 0.3196 - val_accuracy: 0.8606 - 83s/epoch - 83ms/step
# Epoch 40/80
# 998/998 - 84s - loss: 0.2945 - accuracy: 0.8715 - val_loss: 0.2732 - val_accuracy: 0.8849 - 84s/epoch - 85ms/step
# Epoch 41/80
# 998/998 - 84s - loss: 0.2925 - accuracy: 0.8744 - val_loss: 0.2666 - val_accuracy: 0.8879 - 84s/epoch - 84ms/step
# Epoch 42/80
# 998/998 - 83s - loss: 0.2884 - accuracy: 0.8746 - val_loss: 0.3124 - val_accuracy: 0.8648 - 83s/epoch - 83ms/step
# Epoch 43/80
# 998/998 - 83s - loss: 0.2895 - accuracy: 0.8741 - val_loss: 0.2611 - val_accuracy: 0.8927 - 83s/epoch - 84ms/step
# Epoch 44/80
# 998/998 - 84s - loss: 0.2873 - accuracy: 0.8773 - val_loss: 0.2873 - val_accuracy: 0.8841 - 84s/epoch - 84ms/step
# Epoch 45/80
# 998/998 - 84s - loss: 0.2812 - accuracy: 0.8785 - val_loss: 0.2412 - val_accuracy: 0.8959 - 84s/epoch - 84ms/step
# Epoch 46/80
# 998/998 - 83s - loss: 0.2787 - accuracy: 0.8815 - val_loss: 0.2563 - val_accuracy: 0.8901 - 83s/epoch - 84ms/step
# Epoch 47/80
# 998/998 - 83s - loss: 0.2799 - accuracy: 0.8801 - val_loss: 0.2824 - val_accuracy: 0.8802 - 83s/epoch - 84ms/step
# Epoch 48/80
# 998/998 - 83s - loss: 0.2736 - accuracy: 0.8831 - val_loss: 0.3096 - val_accuracy: 0.8656 - 83s/epoch - 83ms/step
# Epoch 49/80
# 998/998 - 84s - loss: 0.2721 - accuracy: 0.8857 - val_loss: 0.3147 - val_accuracy: 0.8576 - 84s/epoch - 84ms/step
# Epoch 50/80
# 998/998 - 84s - loss: 0.2747 - accuracy: 0.8825 - val_loss: 0.2605 - val_accuracy: 0.8857 - 84s/epoch - 85ms/step
# Epoch 51/80
# 998/998 - 84s - loss: 0.2649 - accuracy: 0.8871 - val_loss: 0.3327 - val_accuracy: 0.8540 - 84s/epoch - 84ms/step
# Epoch 52/80
# 998/998 - 85s - loss: 0.2668 - accuracy: 0.8911 - val_loss: 0.2703 - val_accuracy: 0.8883 - 85s/epoch - 85ms/step
# Epoch 53/80
# 998/998 - 84s - loss: 0.2664 - accuracy: 0.8861 - val_loss: 0.3115 - val_accuracy: 0.8630 - 84s/epoch - 84ms/step
# Epoch 54/80
# 998/998 - 84s - loss: 0.2626 - accuracy: 0.8919 - val_loss: 0.2827 - val_accuracy: 0.8812 - 84s/epoch - 84ms/step
# Epoch 55/80
# 998/998 - 84s - loss: 0.2625 - accuracy: 0.8881 - val_loss: 0.2393 - val_accuracy: 0.9009 - 84s/epoch - 85ms/step
# Epoch 56/80
# 998/998 - 84s - loss: 0.2627 - accuracy: 0.8882 - val_loss: 0.2837 - val_accuracy: 0.8851 - 84s/epoch - 84ms/step
# Epoch 57/80
# 998/998 - 84s - loss: 0.2605 - accuracy: 0.8884 - val_loss: 0.2878 - val_accuracy: 0.8853 - 84s/epoch - 84ms/step
# Epoch 58/80
# 998/998 - 83s - loss: 0.2600 - accuracy: 0.8894 - val_loss: 0.2524 - val_accuracy: 0.8903 - 83s/epoch - 84ms/step
# Epoch 59/80
# 998/998 - 84s - loss: 0.2591 - accuracy: 0.8894 - val_loss: 0.2727 - val_accuracy: 0.8855 - 84s/epoch - 85ms/step
# Epoch 60/80
# 998/998 - 84s - loss: 0.2569 - accuracy: 0.8894 - val_loss: 0.3466 - val_accuracy: 0.8441 - 84s/epoch - 84ms/step
# Epoch 61/80
# 998/998 - 84s - loss: 0.2505 - accuracy: 0.8959 - val_loss: 0.2509 - val_accuracy: 0.8971 - 84s/epoch - 84ms/step
# Epoch 62/80
# 998/998 - 84s - loss: 0.2508 - accuracy: 0.8922 - val_loss: 0.2844 - val_accuracy: 0.8798 - 84s/epoch - 84ms/step
# Epoch 63/80
# 998/998 - 84s - loss: 0.2478 - accuracy: 0.8980 - val_loss: 0.3248 - val_accuracy: 0.8660 - 84s/epoch - 84ms/step
# Epoch 64/80
# 998/998 - 84s - loss: 0.2481 - accuracy: 0.8953 - val_loss: 0.2321 - val_accuracy: 0.9015 - 84s/epoch - 84ms/step
# Epoch 65/80
# 998/998 - 84s - loss: 0.2492 - accuracy: 0.8960 - val_loss: 0.2590 - val_accuracy: 0.8899 - 84s/epoch - 84ms/step
# Epoch 66/80
# 998/998 - 84s - loss: 0.2479 - accuracy: 0.8962 - val_loss: 0.2272 - val_accuracy: 0.9043 - 84s/epoch - 84ms/step
# Epoch 67/80
# 998/998 - 83s - loss: 0.2465 - accuracy: 0.8963 - val_loss: 0.2493 - val_accuracy: 0.8929 - 83s/epoch - 83ms/step
# Epoch 68/80
# 998/998 - 84s - loss: 0.2495 - accuracy: 0.8954 - val_loss: 0.2737 - val_accuracy: 0.8847 - 84s/epoch - 84ms/step
# Epoch 69/80
# 998/998 - 84s - loss: 0.2392 - accuracy: 0.9003 - val_loss: 0.2374 - val_accuracy: 0.9099 - 84s/epoch - 84ms/step
# Epoch 70/80
# 998/998 - 84s - loss: 0.2442 - accuracy: 0.8987 - val_loss: 0.3361 - val_accuracy: 0.8684 - 84s/epoch - 84ms/step
# Epoch 71/80
# 998/998 - 85s - loss: 0.2409 - accuracy: 0.8971 - val_loss: 0.2768 - val_accuracy: 0.8802 - 85s/epoch - 85ms/step
# Epoch 72/80
# 998/998 - 84s - loss: 0.2413 - accuracy: 0.9016 - val_loss: 0.2334 - val_accuracy: 0.8999 - 84s/epoch - 84ms/step
# Epoch 73/80
# 998/998 - 85s - loss: 0.2413 - accuracy: 0.8998 - val_loss: 0.2275 - val_accuracy: 0.9109 - 85s/epoch - 85ms/step
# Epoch 74/80
# 998/998 - 84s - loss: 0.2412 - accuracy: 0.8996 - val_loss: 0.2580 - val_accuracy: 0.8895 - 84s/epoch - 84ms/step
# Epoch 75/80
# 998/998 - 84s - loss: 0.2385 - accuracy: 0.9004 - val_loss: 0.2848 - val_accuracy: 0.8800 - 84s/epoch - 84ms/step
# Epoch 76/80
# 998/998 - 85s - loss: 0.2388 - accuracy: 0.9005 - val_loss: 0.2357 - val_accuracy: 0.9011 - 85s/epoch - 85ms/step
# Epoch 77/80
# 998/998 - 84s - loss: 0.2404 - accuracy: 0.8997 - val_loss: 0.2665 - val_accuracy: 0.9035 - 84s/epoch - 84ms/step
# Epoch 78/80
# 998/998 - 84s - loss: 0.2334 - accuracy: 0.9016 - val_loss: 0.2639 - val_accuracy: 0.8963 - 84s/epoch - 84ms/step
# Epoch 79/80
# 998/998 - 84s - loss: 0.2390 - accuracy: 0.9002 - val_loss: 0.2313 - val_accuracy: 0.9047 - 84s/epoch - 84ms/step
# Epoch 80/80
# 998/998 - 84s - loss: 0.2391 - accuracy: 0.9030 - val_loss: 0.3675 - val_accuracy: 0.8566 - 84s/epoch - 84ms/step

# %%
# Plot the results of training with data augmentation
plot_loss_acc(history_with_aug)

# %% [markdown]
# As you can see, the training accuracy has gone down compared to the baseline. This is expected because (as a result of data augmentation) there are more variety in the images so the model will need more runs to learn from them. The good thing is the validation accuracy is no longer stalling and is more in line with the training results. This means that the model is now performing better on unseen data.

# %% [markdown]
# ## Wrap Up
#
# This exercise showed a simple trick to avoid overfitting. You can improve your baseline results by simply tweaking the same images you have already. The image augmentation preprocessing layers will do just that. Try to modify the values in the augmentation model and see what results you get. You can also add other preprocessing layers for random contrast, brightness, or cropping.
#
# Take note that this will not work for all cases. In the next lesson, Laurence will show a scenario where data augmentation will not help improve your validation accuracy.
#
# Before going back to the classroom, run the cell below to free up resources for the next lab. You might see a pop-up about restarting the kernel afterwards. You can safely ignore it and just press Ok. You can then close this lab, then go back to the classroom for the next lecture. See you there!

# %%
# Shutdown the kernel to free up resources. 
# Note: You can expect a pop-up when you run this cell. You can safely ignore that and just press `Ok`.

from IPython import get_ipython

k = get_ipython().kernel

k.do_shutdown(restart=False)
# Out:
# {'status': 'ok', 'restart': False}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
